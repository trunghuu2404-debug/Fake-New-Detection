# %% [markdown]
# # Explore datset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Running cells with 'Python 3.12.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
cd /content/drive/MyDrive/AI Project
# Out:
# /content/drive/MyDrive/AI Project

# %%
import pandas as pd
import numpy as np

# %%
import os
for dirname, _, filenames in os.walk('dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# dataset/Fake.csv
# dataset/True.csv

# %%
#loading all data
fake = pd.read_csv('dataset/Fake.csv')
true = pd.read_csv('dataset/True.csv')

# %%
fake.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake.tail(5)
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date
# 23476  January 16, 2016
# 23477  January 16, 2016
# 23478  January 15, 2016
# 23479  January 14, 2016
# 23480  January 12, 2016

# %%
fake["subject"].value_counts()
# Out:
# subject
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
true.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true.tail(5)
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
true["subject"].value_counts()
# Out:
# subject
# politicsNews    11272
# worldnews       10145
# Name: count, dtype: int64

# %%
#create label for whether fake or true, 0 for true, 1 for fake
fake['category'] = 1
true['category'] = 0

# %%
true.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  category
# 0  December 31, 2017          0
# 1  December 29, 2017          0
# 2  December 31, 2017          0
# 3  December 30, 2017          0
# 4  December 29, 2017          0

# %%
fake.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  category
# 0  December 31, 2017         1
# 1  December 31, 2017         1
# 2  December 30, 2017         1
# 3  December 29, 2017         1
# 4  December 25, 2017         1

# %%
df = pd.concat([fake, true]).reset_index(drop=True)
# reset index, or else some row would have the same index when join two dataset

# %%
# check the new dataframe
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 7))
sns.countplot(x='category', data=df)
plt.title("Distribution of News Articles")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,7))

sns.countplot(x="subject", data=df, palette='Set1')

plt.title("Distribution of News Articles")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()
# Out:
# /var/folders/jy/0vdnv0tj33797_zjrdlnb5p40000gn/T/ipykernel_7371/551376621.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="subject", data=df, palette='Set1')

# %% [markdown]
# Since we only extract 3 feature in the dataset: Title, text and category, we will drop 'subject' and 'date' column as these can ultimately affect the accuracy

# %%
df = df[['title', 'text', 'category']]

# %%
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text  category
# 0      Donald Trump just couldn t wish all Americans ...         1
# 1      House Intelligence Committee Chairman Devin Nu...         1
# 2      On Friday, it was revealed that former Milwauk...         1
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First step of cleaning our dataset is to check if there is any missing value in our dataset

# %%
df.isna().sum()*100/len(df)
# Out:
# title       0.0
# text        0.0
# category    0.0
# dtype: float64

# %% [markdown]
# We can see there is no missing value. However, we not sure if there is any anomolies in each row, e.g a space " ", can be count as String
#
# Therefore, we will then explore if there is any empty string in 'Title' and 'Text' column.

# %%
# Blank indices for 'text'
text_blanks = []
for index, text in df['text'].items():
    if isinstance(text, str):          # make sure it's a string
        if text.strip() == "":         # catches "" and "   "
            text_blanks.append(index)

# Blank indices for 'title'
title_blanks = []
for index, title in df['title'].items():
    if isinstance(title, str):
        if title.strip() == "":
            title_blanks.append(index)

print("Empty text rows:", len(text_blanks))
print("Empty title rows:", len(title_blanks))
# Out:
# Empty text rows: 631
# Empty title rows: 0

# %% [markdown]
# So we appear to have missing value in 'text' column only.

# %%
text_blanks # see which row has empty string
# Out:
# [10923,
#  11041,
#  11190,
#  11225,
#  11236,
#  11241,
#  11247,
#  11249,
#  11267,
#  11268,
#  11283,
#  11284,
#  11285,
#  11289,
#  11290,
#  11292,
#  11295,
#  11296,
#  11301,
#  11303,
#  11304,
#  11305,
#  11309,
#  11314,
#  11317,
#  11319,
#  11322,
#  11330,
#  11334,
#  11335,
#  11340,
#  11343,
#  11348,
#  11351,
#  11352,
#  11357,
#  11371,
#  11373,
#  11374,
#  11382,
#  11397,
#  11402,
#  11403,
#  11409,
#  11410,
#  11412,
#  11415,
#  11419,
#  11421,
#  11427,
#  11431,
#  11432,
#  11440,
#  11448,
#  11450,
#  11453,
#  11462,
#  11464,
#  11465,
#  11472,
#  11473,
#  11475,
#  11478,
#  11489,
#  11491,
#  11493,
#  11494,
#  11501,
#  11505,
#  11507,
#  11520,
#  11531,
#  11532,
#  11533,
#  11538,
#  11542,
#  11547,
#  11549,
#  11551,
#  11559,
#  11563,
#  11581,
#  11585,
#  11589,
#  11590,
#  11614,
#  11624,
#  11625,
#  11627,
#  11631,
#  11636,
#  11637,
#  11643,
#  11650,
#  11658,
#  11661,
#  11672,
#  11679,
#  11681,
#  11684,
# ...

# %%
#see what it looks like in a row with empty string
df['text'][12940]
# Out:
# ' '

# %%
df.shape
# Out:
# (44898, 3)

# %% [markdown]
# Now we begin to remove rows that contain missing value

# %%
df.drop(text_blanks, inplace=True)
# Out:
# /var/folders/jy/0vdnv0tj33797_zjrdlnb5p40000gn/T/ipykernel_7371/3951194466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(text_blanks, inplace=True)

# %%
df.shape
# Out:
# (44267, 3)

# %% [markdown]
# As you can see, the size of the dataset is degraded from (44898, 3) to (44267, 3)

# %% [markdown]
# Next step is to clean our text data, in this case it would be **stop word**

# %% [markdown]
# **STOP WORLD**
#
# In Natural Language Processing (NLP), stop words are common words that are usually ignored during text processing because they carry little meaningful information.
#
# Examples: "the", "is", "at", "on", "and", "a", "of", "in"
#
# They appear very frequently in text but don’t help distinguish meaning in tasks like classification or information retrieval. Therefore, we dont want them too take up space in our database, or taking up valuable processing time. We do this by simply storing a list of words that you consider to stop words.

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer # word with similar
                                        # context will be only consider as one
                                        # e.g: talk and talking
import spacy
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')

nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>

# %%
lemma = WordNetLemmatizer()

# %%
#stop word of spacy
list1 = nlp.Defaults.stop_words
print(len(list1))

#stoopword of NTLK
list2 = stopwords.words('english')
print(len(list2))

#combining the stopword list

Stopword = set((set(list1)|set(list2)))
print(len(Stopword))
# Out:
# 326
# 198
# 401

# %%
def clean_text(text):

    """
    It takes text as an input and clean it by applying several methods

    """

    string = ""

    #lower casing
    text=text.lower()
    #simplifying text
    text=re.sub(r"i'm","i am",text)
    text=re.sub(r"he's","he is",text)
    text=re.sub(r"she's","she is",text)
    text=re.sub(r"that's","that is",text)
    text=re.sub(r"what's","what is",text)
    text=re.sub(r"where's","where is",text)
    text=re.sub(r"\'ll"," will",text)
    text=re.sub(r"\'ve"," have",text)
    text=re.sub(r"\'re"," are",text)
    text=re.sub(r"\'d"," would",text)
    text=re.sub(r"won't","will not",text)
    text=re.sub(r"can't","cannot",text)

    #removing any special character
    text=re.sub(r"[-()\"#!@$%^&*{}?.,:]"," ",text)
    text=re.sub(r"\s+"," ",text)
    text=re.sub('[^A-Za-z0-9]+',' ', text)

    for word in text.split():
        if word not in Stopword:
            string+=lemma.lemmatize(word)+" "

    return string

# %%
#cleaning the whole data
df["title"] = df["title"].apply(clean_text)
df["text"]=df["text"].apply(clean_text)
# Out:
# /var/folders/jy/0vdnv0tj33797_zjrdlnb5p40000gn/T/ipykernel_7371/3105221372.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["title"] = df["title"].apply(clean_text)
# /var/folders/jy/0vdnv0tj33797_zjrdlnb5p40000gn/T/ipykernel_7371/3105221372.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text"]=df["text"].apply(clean_text)

# %% [markdown]
# # Feature-Extraction & Model building

# %%
df["title"]
# Out:
# 0        donald trump sends embarrassing new year eve m...
# 1        drunk bragging trump staffer started russian c...
# 2        sheriff david clarke internet joke threatening...
# 3                trump obsessed obama coded website image
# 4        pope francis called donald trump christmas spe...
#                                ...
# 44893    fully committed nato back new u approach afgha...
# 44894          lexisnexis withdrew product chinese market
# 44895                        minsk cultural hub authority
# 44896    vatican upbeat possibility pope francis visiti...
# 44897        indonesia buy 1 14 billion worth russian jet
# Name: title, Length: 44267, dtype: object

# %%
df["text"]
# Out:
# 0        donald trump wish american happy new year leav...
# 1        house intelligence committee chairman devin nu...
# 2        friday revealed milwaukee sheriff david clarke...
# 3        christmas day donald trump announced work foll...
# 4        pope francis annual christmas day message rebu...
#                                ...
# 44893    brussels reuters nato ally tuesday welcomed pr...
# 44894    london reuters lexisnexis provider legal regul...
# 44895    minsk reuters shadow disused soviet era factor...
# 44896    moscow reuters vatican secretary state cardina...
# 44897    jakarta reuters indonesia buy 11 sukhoi fighte...
# Name: text, Length: 44267, dtype: object

# %%
df["category"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 44893    0
# 44894    0
# 44895    0
# 44896    0
# 44897    0
# Name: category, Length: 44267, dtype: int64

# %%
#splitting the dataset - training: 67%, testing: 33%
from sklearn.model_selection import train_test_split

# Combine title and text into one feature
X = df["title"] + " " + df["text"]
y=df["category"] # target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## SVM

# %%
#importing libraries to build a pipline
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# %%
#this pipe line will take the text and vectorise it , and then TF-IDF, then fitting the model

text_clf=Pipeline([("tfidf",TfidfVectorizer()),("clf",LinearSVC())])
text_clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
#making prediction using the model
predictions=text_clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_curve, auc, precision_recall_curve, classification_report
train_accuracy = text_clf.score(X_train, y_train)
test_accuracy = accuracy_score(y_test, predictions)

print(f"Training Accuracy: {train_accuracy:.3f}")
print(f"Testing Accuracy: {test_accuracy:.3f}")
# Out:
# Training Accuracy: 1.000
# Testing Accuracy: 0.994

# %%
cm = confusion_matrix(y_test, predictions, labels=text_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=text_clf.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
if len(np.unique(y_test)) == 2:
    y_score = text_clf.decision_function(X_test)  # SVM decision function
    fpr, tpr, thresholds = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6,4))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')
    plt.plot([0,1], [0,1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.show()

    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_score)
    plt.figure(figsize=(6,4))
    plt.plot(recall, precision, color='purple', lw=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.show()

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7047
#            1       0.99      0.99      0.99      7562
#
#     accuracy                           0.99     14609
#    macro avg       0.99      0.99      0.99     14609
# weighted avg       0.99      0.99      0.99     14609

# %%
#overall acuracy
print(accuracy_score(y_test,predictions))
# Out:
# 0.9942501197891711

# %% [markdown]
# Lastly, save the model for future work.

# %%
import joblib

# Save the trained model to a file
joblib.dump(text_clf, "fake_news_model.pkl")
# Out:
# ['fake_news_model.pkl']

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# %%
# Create a pipeline with TF-IDF vectorizer + Logistic Regression
lr_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(
        stop_words='english',
        max_df=0.7,
        ngram_range=(1, 2),  # Use unigrams + bigrams for better context
        max_features=50000    # Limit vocab size for performance
    )),
    ('lr', LogisticRegression(
        C=1.0,
        max_iter=1000,
        solver='liblinear'
    ))
])

# %%
lr_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.7, max_features=50000,
#                                  ngram_range=(1, 2), stop_words='english')),
#                 ('lr', LogisticRegression(max_iter=1000, solver='liblinear'))])

# %%
y_pred_lr = lr_pipeline.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("\nClassification Report:\n", classification_report(y_test, y_pred_lr))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
# Out:
# Accuracy: 0.9856937504278185
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7047
#            1       0.99      0.99      0.99      7562
#
#     accuracy                           0.99     14609
#    macro avg       0.99      0.99      0.99     14609
# weighted avg       0.99      0.99      0.99     14609
#
#
# Confusion Matrix:
#  [[6951   96]
#  [ 113 7449]]

# %%
joblib.dump(lr_pipeline, 'fake_news_logistic_regression.pkl')
# Out:
# ['fake_news_logistic_regression.pkl']

# %%
loaded_model = joblib.load('fake_news_logistic_regression.pkl')

sample = ["Donald Trump says aliens visited Earth, White House confirms"]
prediction = loaded_model.predict(sample)
print("Prediction:", "Fake" if prediction[0] == 1 else "Real")
# Out:
# Prediction: Fake

# %%
# from sklearn.model_selection import GridSearchCV

# param_grid = {
#     'tfidf__max_df': [0.7, 0.9, 1.0],
#     'tfidf__ngram_range': [(1, 1), (1, 2)],
#     'lr__C': [0.1, 1, 10]
# }

# grid = GridSearchCV(lr_pipeline, param_grid, cv=3, scoring='accuracy', verbose=2)
# grid.fit(X_train, y_train)

# print("Best Parameters:", grid.best_params_)
# print("Best Score:", grid.best_score_)

# joblib.dump(grid.best_estimator_, 'fake_news_lr_best.pkl')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict using your logistic regression pipeline
y_pred_lr = lr_pipeline.predict(X_test)

# Confusion matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(6,4))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities
y_prob_lr = lr_pipeline.predict_proba(X_test)[:,1]

# Compute ROC curve and AUC
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_prob_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)

plt.figure(figsize=(6,4))
plt.plot(fpr_lr, tpr_lr, color='darkorange', lw=2,
         label=f'ROC Curve (AUC = {roc_auc_lr:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np

# Extract TF-IDF vectorizer and Logistic Regression model
tfidf_lr = lr_pipeline.named_steps['tfidf']
logreg = lr_pipeline.named_steps['lr']

# Get feature names and coefficients
feature_names_lr = tfidf_lr.get_feature_names_out()
coefficients_lr = logreg.coef_[0]

# Top 20 positive (fake) and negative (real) words
top_fake_lr = np.argsort(coefficients_lr)[-20:]
top_real_lr = np.argsort(coefficients_lr)[:20]

plt.figure(figsize=(10,6))
plt.barh(feature_names_lr[top_fake_lr], coefficients_lr[top_fake_lr], color='red')
plt.barh(feature_names_lr[top_real_lr], coefficients_lr[top_real_lr], color='green')
plt.xlabel('Coefficient Value')
plt.title('Top Words Associated with Fake (Red) and Real (Green) News - Logistic Regression')
plt.show()

# %%
sns.countplot(x=y_train)
plt.title('Distribution of Fake (1) and Real (0) News in Training Data')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import joblib

# %% [markdown]
# # Multinomial Naive Bayes

# %%
mnb_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english', 
                               max_df=0.7,
                             ngram_range=(1,2), 
                             max_features=50000)),
    ('mnb', MultinomialNB(alpha=0.5))
])

# %%
mnb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.7, max_features=50000,
#                                  ngram_range=(1, 2), stop_words='english')),
#                 ('mnb', MultinomialNB(alpha=0.5))])

# %%
y_pred_mnb = mnb_pipeline.predict(X_test)

print("MultinomialNB Accuracy:", accuracy_score(y_test, y_pred_mnb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_mnb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_mnb))
# Out:
# MultinomialNB Accuracy: 0.9516736258470806
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      7047
#            1       0.95      0.96      0.95      7562
#
#     accuracy                           0.95     14609
#    macro avg       0.95      0.95      0.95     14609
# weighted avg       0.95      0.95      0.95     14609
#
#
# Confusion Matrix:
#  [[6642  405]
#  [ 301 7261]]

# %%
joblib.dump(mnb_pipeline, 'fake_news_multinomial_nb.pkl')
# Out:
# ['fake_news_multinomial_nb.pkl']

# %%
loaded_mnb = joblib.load('fake_news_multinomial_nb.pkl')
sample = ["Government announces plan to improve education funding"]
prediction = loaded_mnb.predict(sample)

print("Prediction:", "Fake" if prediction[0] == 1 else "Real")
# Out:
# Prediction: Real

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict using your MultinomialNB pipeline
y_pred_mnb = mnb_pipeline.predict(X_test)

# Confusion matrix
cm_mnb = confusion_matrix(y_test, y_pred_mnb)

plt.figure(figsize=(6,4))
sns.heatmap(cm_mnb, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Multinomial Naive Bayes')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities
y_prob_mnb = mnb_pipeline.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr_mnb, tpr_mnb, thresholds_mnb = roc_curve(y_test, y_prob_mnb)
roc_auc_mnb = auc(fpr_mnb, tpr_mnb)

plt.figure(figsize=(6,4))
plt.plot(fpr_mnb, tpr_mnb, color='darkorange', lw=2,
         label=f'ROC Curve (AUC = {roc_auc_mnb:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Multinomial Naive Bayes')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np

# Extract TF-IDF vectorizer and Multinomial Naive Bayes model
tfidf_mnb = mnb_pipeline.named_steps['tfidf']
mnb_model = mnb_pipeline.named_steps['mnb']  # or 'clf' if you named it that way

# Get feature names and relative log probabilities
feature_names_mnb = tfidf_mnb.get_feature_names_out()
coefficients_mnb = mnb_model.feature_log_prob_[1] - mnb_model.feature_log_prob_[0]

# Top 20 positive (fake) and negative (real) words
top_fake_mnb = np.argsort(coefficients_mnb)[-20:]
top_real_mnb = np.argsort(coefficients_mnb)[:20]

plt.figure(figsize=(10,6))
plt.barh(feature_names_mnb[top_fake_mnb], coefficients_mnb[top_fake_mnb], color='red')
plt.barh(feature_names_mnb[top_real_mnb], coefficients_mnb[top_real_mnb], color='green')
plt.xlabel('Relative Log Probability')
plt.title('Top Words Associated with Fake (Red) and Real (Green) News - Multinomial Naive Bayes')
plt.show()

# %% [markdown]
# # Bernoulli Naive Bayes

# %%
bnb_pipeline = Pipeline([
    ('TfidfVectorizer', TfidfVectorizer(stop_words='english', binary=True, max_features=50000)),
    ('BernoulliNB', BernoulliNB(alpha=0.5))
])

# %%
bnb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('TfidfVectorizer',
#                  TfidfVectorizer(binary=True, max_features=50000,
#                                  stop_words='english')),
#                 ('BernoulliNB', BernoulliNB(alpha=0.5))])

# %%
# Predict using your Bernoulli Naive Bayes pipeline
y_pred_bnb = bnb_pipeline.predict(X_test)

print("BernoulliNB Accuracy:", accuracy_score(y_test, y_pred_bnb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_bnb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_bnb))
# Out:
# BernoulliNB Accuracy: 0.9670750906975152
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      7047
#            1       0.97      0.97      0.97      7562
#
#     accuracy                           0.97     14609
#    macro avg       0.97      0.97      0.97     14609
# weighted avg       0.97      0.97      0.97     14609
#
#
# Confusion Matrix:
#  [[6811  236]
#  [ 245 7317]]

# %%
joblib.dump(bnb_pipeline, 'fake_news_bernoulli_nb.pkl')
# Out:
# ['fake_news_bernoulli_nb.pkl']

# %%
loaded_mnb = joblib.load('fake_news_multinomial_nb.pkl')

samples = [
    "Aliens have been found living secretly under the Pacific Ocean"
]

# Predict for each text
for text in samples:
    prediction = loaded_mnb.predict([text])
    print(f"Text: {text}")
    print("Prediction:", "Fake" if prediction[0] == 1 else "Real")
# Out:
# Text: Aliens have been found living secretly under the Pacific Ocean
# Prediction: Real

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict using your Bernoulli Naive Bayes pipeline
y_pred_bnb = bnb_pipeline.predict(X_test)

# Confusion matrix
cm_bnb = confusion_matrix(y_test, y_pred_bnb)

plt.figure(figsize=(6,4))
sns.heatmap(cm_bnb, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Bernoulli Naive Bayes')
plt.show()

# %%
# Get predicted probabilities
y_prob_bnb = bnb_pipeline.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr_bnb, tpr_bnb, thresholds_bnb = roc_curve(y_test, y_prob_bnb)
roc_auc_bnb = auc(fpr_bnb, tpr_bnb)

plt.figure(figsize=(6,4))
plt.plot(fpr_bnb, tpr_bnb, color='green', lw=2,
         label=f'ROC Curve (AUC = {roc_auc_bnb:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Bernoulli Naive Bayes')
plt.legend(loc='lower right')
plt.show()
